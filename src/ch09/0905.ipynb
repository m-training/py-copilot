# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate some sample data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Plot')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータの設定
mu = 0  # 平均
sigma = 1  # 標準偏差

# x軸の値の範囲を設定
x = np.linspace(-5, 5, 100)

# 正規分布の確率密度関数を計算
y = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-(x - mu)**2 / (2 * sigma**2))

# グラフの描画
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Normal Distribution')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 自由度の設定
df = 5

# X二乗分布の確率密度関数を計算
x = np.linspace(0, 20, 100)
y = (1 / (2**(df/2) * np.math.gamma(df/2))) * x**((df/2)-1) * np.exp(-x/2)

# グラフの描画
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Chi-Square Distribution (df=5)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\masuda\AppData\Local\Temp\ipykernel_23828\307314776.py:9: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   y = (1 / (2**(df/2) * np.math.gamma(df/2))) * x**((df/2)-1) * np.exp(-x/2)
